# %% [markdown]
# ## Task 1 - Data **Validation**

# %% [markdown]
# # Data Analyst Associate Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# The original data is 1550 rows and 8 columns. First thing I did was to identify any missing values and replace them with what the directions said. I had to update the category, size,price and rating column. I then had to change the data type of the price column from VARCHAR to DOUBLE PRECISION. I also rounded both the price and the sales column to two decimal points. After cleaning the data, the columns were as follows
#
# **product_id**
# - missing values not possible
#
# **category VARCHAR 50**
# - "Medicine" "Food"  "Equipment" "Unknown" "Accessory" "Housing" "Toys"
# - Replaced any missing values with “Unknown”
#
# **animal VARCHAR 50**
# - "Fish" "Cat" "Bird" "Dog"
# - No missing values
#
# **size VARCHAR 50**
# - "Small" "Large" "Medium"
# - Used “INITCAP” to format sizes in the correct way
#
# **price DOUBLE PRECISION**
# - 2 decimal points
# - Missing values set to 28.86 (median)
# - Change from VARCHAR
#
# **sales double precision**
# - 2 decimal points
# - No missing values
#
# **rating VARCHAR 50**
# - Ratings range from 1 to 9
# - Changed missing values to 0
#
# **repeat_purchase int**
# - No missing values
# - Either 1 or 2

# %% [markdown]
# # Data Discovery and Visualization
# ## Task 2 -How many sales are repeat sales?

# %% [markdown]
# ![Sum of Sales by Repeat_Purchases](Sume_Sales_Repeat_Purchases.jpg)
#
#
#
# There are two values that the repeat_purchases column can have, either a 1 (for it being a product that is repeatedly purchased) or 0 (not purchased repeatedly). The above graph shows that the majority of products sold (905 out of 1500) are products that are repeatedly purchased.
#
# ![Repeat Purchases by different Metrics](Repeat_Purcahses_Diff_Metrics.jpg)
#
# The above graphs show us that repeat purchase products are the most popular in  animal, product category and price range. The only place where there are more non repeated purchased products are those that are rated a 9 on the rating scale.

# %% [markdown]
# ## Task 3 - Distribution of all sales

# %% [markdown]
# ![Pie Chart of all Sales](Sales_Pie.jpg)
# ![Sales broke down my catergory and animal](Sales_Different_Metrics.jpg)
#
#
# Overall cats were the animal that the most purchases were made for. Equipment was the most popular type of product. I further  broke down the category sales by animals. Equipment for cats is the most popular type of purchase. Cats also had the least popular known category  purchases of accessories for cats. Equipment and toys were the most popular for fish. Food was the most popular product for dogs and fish.

# %% [markdown]
# ## Task 4 - Sales and repeat purchases
# ![Sum of Sales by Repeat Purchases](./Sum_Sales_Repeat.jpg)
#
#
#
#
# PetMind made 1.5 Million dollars over the sales period of the given data. With 60% of it being repeat purchased items.  I would continue to focus on the $30-$40 dollar range, as that is where the most products were priced at. In order to increase sales one area to look at would be those items rated 0(no rating was given). The more good ratings a product has, the more likely people will buy it. There could be an incentive program such as the chance to win a prize if one rates the product.

# %% [markdown]
# _Write your answer here_

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam
